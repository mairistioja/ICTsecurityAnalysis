# %%
import numpy as np
import pandas as pd

data = pd.read_csv("spetsialistidVsTurvaintsidendid2.csv")
data2 = data.copy(deep=True)
data2 = data.drop(['Tööga hõivatud isikute arv', 'Tegevusala', 'Näitaja', 'Tegevusala (EMTAK 2008)', 'Turvalisus'], axis=1)
data2

testDistribution = []
for i in range(10000):
    for column in data2.columns:
        np.random.shuffle(data2[column])
    pairwise_correlations = data2.corr()
    pairwise_correlations.values[np.triu_indices_from(pairwise_correlations, 0)] = np.nan
    maxVal = np.max(np.abs(pairwise_correlations.stack()))
    testDistribution.append(maxVal)
    
sigThreshold = np.max(testDistribution)
print(f"threshold: {sigThreshold}")

data3 = data.copy(deep=True)
pairwise_correlations = data3.corr()
pairwise_correlations
# Out:
# threshold: 0.7502068138383869
#             Value   Value.1
# Value    1.000000 -0.694316
# Value.1 -0.694316  1.000000

# %%
# %%time
import numpy as np
import pandas as pd

data = pd.read_csv("kokku.csv")
#data = data.loc[data['Value.1'] == 30.2]
cs = ["Tööga hõivatud isikute arv", "Näitaja", "Turvalisus"] # columns
uvs = [list(pd.unique(data[c])) for c in cs] # unique values
#uvs[1].remove("Kokku – kõik tegevusalad")
corrs = []

def jobs():
    for v0 in uvs[0]:
        for v1 in uvs[1]:
            for v2 in uvs[2]:
                yield v0, v1, v2

for job in jobs(): #list(jobs())[:10]:
    tmp = data.loc[(data[cs[0]] == job[0]) \
                   & (data[cs[1]] == job[1]) \
                   & (data[cs[2]] == job[2])]
    tmp = tmp.loc[tmp["Tegevusala"] != "Kokku – kõik tegevusalad"]
    tmp = tmp.filter(items=["Value", "Value.1"])
    corrs.append((job, tmp.corr().iloc[0, 1]))
corrs
# Out:
# Wall time: 6.4 s
# [(('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Andmete varundamine eraldi keskkonda'),
#   0.7265427164916515),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Andmete, dokumentide, e-kirjade krüpteerimine'),
#   0.692585869540999),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Biomeetrilise meetodi kasutamine kasutaja tuvastamiseks, autentimiseks'),
#   0.4717377049490598),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Dokumendid IKT turvalisuse hindamise, praktikate, protseduuride kohta'),
#   0.8267245331794492),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Eelmisel aastal ei puutunud kokku ühegi IKT turvaintsidendiga'),
#   -0.694316453880585),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Eelmisel aastal kokkupuude IKT turvaintsidendiga, IKT teenused polnud kättesaadavad'),
#   0.7814399322761458),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Eelmisel aastal kokkupuude IKT turvaintsidendiga, andmete hävitamine või rikkumine'),
#   0.30328963659033675),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Eelmisel aastal kokkupuude IKT turvaintsidendiga, konfidentsiaalsete andmete leke'),
#   0.19546439713475003),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Eelmisel aastal kokkupuude vähemalt ühe IKT turvaintsidendiga'),
#   0.6944534427877441),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Ettevõttes IKT spetsialistid ja dokumentatsioon IKT turvalisuse hindamise, praktikate ja protseduuride kohta'),
#   0.9749554565461623),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT alaseid ülesandeid teostab väline teenusepakkuja, IKT turvalisuse ülesandeid enda töötaja'),
#   0.7253479828817591),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT alaseid ülesandeid teostavad enda töötajad, IKT turvalisuse ülesandeid väline teenusepakkuja'),
#   0.5713309945130849),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT alaseid, sealhulgas IKT turvalisusega seotud ülesandeid teostab väline teenusepakkuja'),
#   -0.5008105664938857),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT alaseid, sh IKT turvalisusega seotud ülesandeid teostavad ettevõtte enda töötajad'),
#   0.9402057131974152),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT riskianalüüside teostamine'),
#   0.8147377395008014),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT turvalisuse teemadest ei teavitata'),
#   -0.7049807353883591),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT turvalisuse tegevusi teostab väline teenusepakkuja'),
#   -0.5455501569452154),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT turvalisuse tegevusi teostavad ettevõtte enda töötajad ja väline teenusepakkuja'),
#   0.5607209982595123),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT turvalisuse tegevuste teostajad on ettevõtte enda töötajad'),
#   0.9224426118472485),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'IKT turvalisusega seonduv on fikseeritud lepingus'),
#   0.7153135931919881),
#  (('Kokku', 'IKT-spetsialistidega ettevõtted', 'IKT turvatestid'),
#   0.7951184859052348),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Kasutatakse IKT turvalisuse meetodeid'),
#   0.5470261393765262),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Kindlustus IKT turvaintsidentide vastu'),
#   0.8843649462531699),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Kohustuslikud koolitused, kohustusliku materjali lugemine'),
#   0.7871818804092182),
#  (('Kokku', 'IKT-spetsialistidega ettevõtted', 'Tugev paroolide autentimine'),
#   0.7613607410465307),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Turvaintsidendi logifailide kopeerimine ja säilitamine analüüsiks'),
#   0.8413185112537602),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Turvapoliitikat muudeti viimati 12 kuni 24 kuud tagasi'),
#   -0.032283758948465684),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Turvapoliitikat muudeti viimati rohkem kui 24 kuud tagasi'),
#   0.3133171230839959),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Turvapoliitikat muudeti viimati viimase 12 kuu jooksul'),
#   0.8324428640373277),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Turvapoliitikat muudeti viimati viimase 24 kuu jooksul'),
#   0.7921438265437118),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Töötajaid teavitatakse IKT turvalisusest eri viisidel'),
#   0.7031104815031332),
#  (('Kokku', 'IKT-spetsialistidega ettevõtted', 'VPNi kasutamine'),
#   0.800733059162276),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Vabatahtlik IKT turvalisuse koolitusel osalemine, sisemise teabe edastamine'),
#   0.75091010898384),
#  (('Kokku',
#    'IKT-spetsialistidega ettevõtted',
#    'Värskeimate tarkvara versioonide kasutamine'),
#   0.5589133816685983),
#  (('Kokku', 'IKT-spetsialistidega ettevõtted', 'Võrgujuurdepääsu kontroll'),
#   0.6785887509795318),
#  (('Kokku',
#    'Eelmisel aastal oma IKT-spetsialistidele IKT-koolitust pakkunud ettevõtted',
#    'Andmete varundamine eraldi keskkonda'),
#   0.6999084296415361),
#  (('Kokku',
#    'Eelmisel aastal oma IKT-spetsialistidele IKT-koolitust pakkunud ettevõtted',
#    'Andmete, dokumentide, e-kirjade krüpteerimine'),
#   0.6761576565505316),
#  (('Kokku',
#    'Eelmisel aastal oma IKT-spetsialistidele IKT-koolitust pakkunud ettevõtted',
#    'Biomeetrilise meetodi kasutamine kasutaja tuvastamiseks, autentimiseks'),
#   0.4182993694818188),
#  (('Kokku',
#    'Eelmisel aastal oma IKT-spetsialistidele IKT-koolitust pakkunud ettevõtted',
#    'Dokumendid IKT turvalisuse hindamise, praktikate, protseduuride kohta'),
#   0.8206205025696232),
#  (('Kokku',
#    'Eelmisel aastal oma IKT-spetsialistidele IKT-koolitust pakkunud ettevõtted',
#    'Eelmisel aastal ei puutunud kokku ühegi IKT turvaintsidendiga'),
#   -0.7064759415444695),
#  (('Kokku',
#    'Eelmisel aastal oma IKT-spetsialistidele IKT-koolitust pakkunud ettevõtted',
#    'Eelmisel aastal kokkupuude IKT turvaintsidendiga, IKT teenused polnud kättesaadavad'),
#   0.8103086891436652),
#  (('Kokku',
#    'Eelmisel aastal oma IKT-spetsialistidele IKT-koolitust pakkunud ettevõtted',
#    'Eelmisel aastal kokkupuude IKT turvaintsidendiga, andmete hävitamine või rikkumine'),
#   0.2785472821927112),
#  (('Kokku',
#    'Eelmisel aastal oma IKT-spetsialistidele IKT-koolitust pakkunud ettevõtted',
#    'Eelmisel aastal kokkupuude IKT turvaintsidendiga, konfidentsiaalsete andmete leke'),
#   0.2230916845857916),
#  (('Kokku',
#    'Eelmisel aastal oma IKT-spetsialistidele IKT-koolitust pakkunud ettevõtted',
#    'Eelmisel aastal kokkupuude vähemalt ühe IKT turvaintsidendiga'),
#   0

#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Eelmisel aastal kokkupuude vähemalt ühe IKT turvaintsidendiga'),
#   0.4471452331740561),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Ettevõttes IKT spetsialistid ja dokumentatsioon IKT turvalisuse hindamise, praktikate ja protseduuride kohta'),
#   0.8684720586656884),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT alaseid ülesandeid teostab väline teenusepakkuja, IKT turvalisuse ülesandeid enda töötaja'),
#   0.5332036165437438),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT alaseid ülesandeid teostavad enda töötajad, IKT turvalisuse ülesandeid väline teenusepakkuja'),
#   0.159731432368865),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT alaseid, sealhulgas IKT turvalisusega seotud ülesandeid teostab väline teenusepakkuja'),
#   -0.3997810746856901),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT alaseid, sh IKT turvalisusega seotud ülesandeid teostavad ettevõtte enda töötajad'),
#   0.7143777123669365),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT riskianalüüside teostamine'),
#   0.4198132260471844),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT turvalisuse teemadest ei teavitata'),
#   -0.698903747295603),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT turvalisuse tegevusi teostab väline teenusepakkuja'),
#   -0.41103784907381463),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT turvalisuse tegevusi teostavad ettevõtte enda töötajad ja väline teenusepakkuja'),
#   0.21220062263134423),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT turvalisuse tegevuste teostajad on ettevõtte enda töötajad'),
#   0.6907494027394488),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT turvalisusega seonduv on fikseeritud lepingus'),
#   0.4445096985979714),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'IKT turvatestid'),
#   0.2120108939196022),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Kasutatakse IKT turvalisuse meetodeid'),
#   0.368473460105878),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Kindlustus IKT turvaintsidentide vastu'),
#   0.3968428523878891),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Kohustuslikud koolitused, kohustusliku materjali lugemine'),
#   0.6926847188930693),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Tugev paroolide autentimine'),
#   0.48291508726147475),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Turvaintsidendi logifailide kopeerimine ja säilitamine analüüsiks'),
#   0.22089467560607043),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Turvapoliitikat muudeti viimati 12 kuni 24 kuud tagasi'),
#   0.04918434687590862),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Turvapoliitikat muudeti viimati rohkem kui 24 kuud tagasi'),
#   -0.008895965417055472),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Turvapoliitikat muudeti viimati viimase 12 kuu jooksul'),
#   0.6406181211578169),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Turvapoliitikat muudeti viimati viimase 24 kuu jooksul'),
#   0.8422438449640569),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Töötajaid teavitatakse IKT turvalisusest eri viisidel'),
#   0.6989037472956032),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'VPNi kasutamine'),
#   0.2670617105157564),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Vabatahtlik IKT turvalisuse koolitusel osalemine, sisemise teabe edastamine'),
#   0.6846069140136767),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Värskeimate tarkvara versioonide kasutamine'),
#   0.14540631645415908),
#  (('250 ja enam',
#    'Eelmisel aastal oma töötajatele IKT-koolitust pakkunud ettevõtted',
#    'Võrgujuurdepääsu kontroll'),
#   0.23008504099506458),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Andmete varundamine eraldi keskkonda'),
#   0.39517797556931444),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Andmete, dokumentide, e-kirjade krüpteerimine'),
#   0.49818532671976357),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Biomeetrilise meetodi kasutamine kasutaja tuvastamiseks, autentimiseks'),
#   0.14696925990214504),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Dokumendid IKT turvalisuse hindamise, praktikate, protseduuride kohta'),
#   0.5882984600495316),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Eelmisel aastal ei puutunud kokku ühegi IKT turvaintsidendiga'),
#   -0.1591156421329751),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Eelmisel aastal kokkupuude IKT turvaintsidendiga, IKT teenused polnud kättesaadavad'),
#   0.26998824071706307),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Eelmisel aastal kokkupuude IKT turvaintsidendiga, andmete hävitamine või rikkumine'),
#   0.17730209499471514),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Eelmisel aastal kokkupuude IKT turvaintsidendiga, konfidentsiaalsete andmete leke'),
#   0.22206261679723885),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Eelmisel aastal kokkupuude vähemalt ühe IKT turvaintsidendiga'),
#   0.15915060380142673),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'Ettevõttes IKT spetsialistid ja dokumentatsioon IKT turvalisuse hindamise, praktikate ja protseduuride kohta'),
#   0.763301625951097),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT alaseid ülesandeid teostab väline teenusepakkuja, IKT turvalisuse ülesandeid enda töötaja'),
#   0.2754993893718609),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT alaseid ülesandeid teostavad enda töötajad, IKT turvalisuse ülesandeid väline teenusepakkuja'),
#   -0.22065766596814965),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT alaseid, sealhulgas IKT turvalisusega seotud ülesandeid teostab väline teenusepakkuja'),
#   -0.3706538672620961),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT alaseid, sh IKT turvalisusega seotud ülesandeid teostavad ettevõtte enda töötajad'),
#   0.3600629026023576),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT riskianalüüside teostamine'),
#   0.8586216730423155),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT turvalisuse teemadest ei teavitata'),
#   -0.5205840019677798),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT turvalisuse tegevusi teostab väline teenusepakkuja'),
#   -0.3013660552810898),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT turvalisuse tegevusi teostavad ettevõtte enda töötajad ja väline teenusepakkuja'),
#   0.22159509425458962),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT turvalisuse tegevuste teostajad on ettevõtte enda töötajad'),
#   0.36731667228555936),
#  (('250 ja enam',
#    'Eelmisel aastal IKT-spetsialisti värvanud / värvata üritanud ettevõtted',
#    'IKT turvalisusega seonduv on fikseeritud lepingus'),
#   0.5042237452895378),
#  ...]

# %% [markdown]
# **Security incidents among companies.**

# %%
#Data about security incidents
import numpy as np
import pandas as pd
pd.options.display.max_columns = None
ictsecurity_data = pd.read_csv("IKTTurvalisus.csv", sep=';')
ictsecurity_data
filtered_data = ictsecurity_data.drop(ictsecurity_data.columns[[0,5,7,9]], axis=1)
filtered_data
incidents = filtered_data[(filtered_data['DIM5'] > 29) & (filtered_data['Turvalisus'] != 'Kindlustus IKT turvaintsidentide vastu') ]
incidents
# Out:
#                       Tegevusala Tööga hõivatud isikute arv  DIM5  \
# 29             Tegevusalad kokku                      Kokku    30
# 30             Tegevusalad kokku                      Kokku    31
# 31             Tegevusalad kokku                      Kokku    32
# 32             Tegevusalad kokku                      Kokku    33
# 33             Tegevusalad kokku                      Kokku    34
# ...                          ...                        ...   ...
# 5384  Muud teenindavad tegevused                      20-49    30
# 5385  Muud teenindavad tegevused                      20-49    31
# 5386  Muud teenindavad tegevused                      20-49    32
# 5387  Muud teenindavad tegevused                      20-49    33
# 5388  Muud teenindavad tegevused                      20-49    34
#
#                                              Turvalisus  Vaatlusperiood  \
# 29    Eelmisel aastal kokkupuude IKT turvaintsidendi...            2019
# 30    Eelmisel aastal kokkupuude IKT turvaintsidendi...            2019
# 31    Eelmisel aastal kokkupuude IKT turvaintsidendi...            2019
# 32    Eelmisel aastal kokkupuude vähemalt ühe IKT tu...            2019
# 33    Eelmisel aastal ei puutunud kokku ühegi IKT tu...            2019
# ...                                                 ...             ...
# 5384  Eelmisel aastal kokkupuude IKT turvaintsidendi...            2019
# 5385  Eelmisel aastal kokkupuude IKT turvaintsidendi...            2019
# 5386  Eelmisel aastal kokkupuude IKT turvaintsidendi...            2019
# 5387  Eelmisel aastal kokkupuude vähemalt ühe IKT tu...            2019
# 5388  Eelmisel aastal ei puutunud kokku ühegi IKT tu...            2019
#
#      Osatähtsus
# 29          6,1
# 30            4
# 31          3,3
# 32          9,2
# 33         90,6
# ...         ...
# 5384       12,5
# 5385          0
# 5386          0
# 5387       12,5
# 5388       87,5
#
# [770 rows x 6 columns]

# %%
#TODO: Second table: data about security indicators and methods
many_indicators = filtered_data.DIM5 < 30  
one_indicator = filtered_data.DIM5 == 35
all_filters = many_indicators | one_indicator
indicators = filtered_data[all_filters]
indicators
# Out:
#                       Tegevusala Tööga hõivatud isikute arv  DIM5  \
# 0              Tegevusalad kokku                      Kokku     1
# 1              Tegevusalad kokku                      Kokku     2
# 2              Tegevusalad kokku                      Kokku     3
# 3              Tegevusalad kokku                      Kokku     4
# 4              Tegevusalad kokku                      Kokku     5
# ...                          ...                        ...   ...
# 5380  Muud teenindavad tegevused                      20-49    26
# 5381  Muud teenindavad tegevused                      20-49    27
# 5382  Muud teenindavad tegevused                      20-49    28
# 5383  Muud teenindavad tegevused                      20-49    29
# 5389  Muud teenindavad tegevused                      20-49    35
#
#                                              Turvalisus  Vaatlusperiood  \
# 0                           Tugev paroolide autentimine            2019
# 1           Värskeimate tarkvara versioonide kasutamine            2019
# 2     Biomeetrilise meetodi kasutamine kasutaja tuva...            2019
# 3         Andmete, dokumentide, e-kirjade krüpteerimine            2019
# 4                  Andmete varundamine eraldi keskkonda            2019
# ...                                                 ...             ...
# 5380  Turvapoliitikat muudeti viimati viimase 12 kuu...            2019
# 5381  Turvapoliitikat muudeti viimati 12 kuni 24 kuu...            2019
# 5382  Turvapoliitikat muudeti viimati rohkem kui 24 ...            2019
# 5383  Turvapoliitikat muudeti viimati viimase 24 kuu...            2019
# 5389             Kindlustus IKT turvaintsidentide vastu            2019
#
#      Osatähtsus
# 0          61,1
# 1          70,7
# 2           6,6
# 3          30,2
# 4          64,6
# ...         ...
# 5380        6,3
# 5381        6,3
# 5382          0
# 5383       12,5
# 5389       12,5
#
# [4620 rows x 6 columns]

# %% [markdown]
# **Getting the numbers of different companies from the Estonian Tax and Customs Board
# (Eesti Maksu- ja Tolliamet) dataset and grouping them by size and by fields of activity
# using Jupyter Notebook: 5h (Tõnis Rahe).**

# %%
import numpy as np
import pandas as pd
taxes_data = pd.read_csv("tasutud_maksud_2019_iv_kvartal.csv", sep=';')
#uniquev = taxes_data['tegevusvaldkond'].unique()
#print(uniquev)
# EI TEA, KAS TULEB TEHA DEEPCOPY VÕI MITTE (POLE KINDEL, KAS MUUDAB CSV FAILI SISU VÕI MITTE) ???
taxes_data['Tootajaid'] = pd.to_numeric(taxes_data['Tootajaid'],errors='coerce')
taxes_data = taxes_data.replace(np.nan, 0, regex=True)
taxes_data['Tootajaid'] = taxes_data['Tootajaid'].astype(int)
taxes_data.groupby(['tegevusvaldkond']).agg({'Nimi': 'count', 'Tootajaid': 'sum'})
#sum_df= taxes_data.groupby(['tegevusvaldkond']).agg({'Nimi'})
# Out:
#                                                      Nimi  Tootajaid
# tegevusvaldkond
# 0                                                    3580       2977
#  AVALIK HALDUS JA RIIGIKAITSE; KOHUSTUSLIK SOTS...    257      41632
# EHITUS                                              14080      51667
# EKSTERRITORIAALSETE ORGANISATSIOONIDE JA ÜKSUST...      2         11
# ELEKTRIENERGIA, GAASI, AURU JA KONDITSIONEERITU...    392       5150
# FINANTS- JA KINDLUSTUSTEGEVUS                        2104      13962
# HALDUS- JA ABITEGEVUSED                              7428      43964
# HARIDUS                                              3513      67837
# HULGI- JA JAEKAUBANDUS; MOOTORSÕIDUKITE JA MOOT...  21127      96727
# INFO JA SIDE                                         8741      30484
# KINNISVARAALANE TEGEVUS                             15928      25029
# KODUMAJAPIDAMISTE KUI TÖÖANDJATE TEGEVUS; KODUM...      2          3
# KUNST, MEELELAHUTUS JA VABA AEG                      5058      21037
# KUTSE-, TEADUS- JA TEHNIKAALANE TEGEVUS             18193      37398
# MAJUTUS JA TOITLUSTUS                                3935      30793
# MUUD TEENINDAVAD TEGEVUSED                           7006      17394
# MÄETÖÖSTUS                                            183       3593
# PÕLLUMAJANDUS, METSAMAJANDUS JA KALAPÜÜK             8108      15892
# TERVISHOID JA SOTSIAALHOOLEKANNE                     2452      49592
# TÖÖTLEV TÖÖSTUS                                      9028     110923
# VEEVARUSTUS; KANALISATSIOON; JÄÄTME- JA SAASTEK...    382       3945
# VEONDUS JA LAONDUS                                   6884      42247

# %%
#Number of employees in the enterprises: 10-19
filtered1 = taxes_data[(taxes_data['Tootajaid'] > 9) & (taxes_data['Tootajaid'] < 20) ][['tegevusvaldkond','Nimi','Tootajaid']]
filtered1.groupby(['tegevusvaldkond']).agg({'Nimi':'count','Tootajaid':'sum'})
# Out:
#                                                     Nimi  Tootajaid
# tegevusvaldkond
# 0                                                     14        191
#  AVALIK HALDUS JA RIIGIKAITSE; KOHUSTUSLIK SOTS...    18        256
# EHITUS                                               781      10329
# EKSTERRITORIAALSETE ORGANISATSIOONIDE JA ÜKSUST...     1         10
# ELEKTRIENERGIA, GAASI, AURU JA KONDITSIONEERITU...    17        227
# FINANTS- JA KINDLUSTUSTEGEVUS                         59        775
# HALDUS- JA ABITEGEVUSED                              243       3307
# HARIDUS                                              316       4522
# HULGI- JA JAEKAUBANDUS; MOOTORSÕIDUKITE JA MOOT...   769      10175
# INFO JA SIDE                                         175       2442
# KINNISVARAALANE TEGEVUS                              140       1785
# KUNST, MEELELAHUTUS JA VABA AEG                      193       2510
# KUTSE-, TEADUS- JA TEHNIKAALANE TEGEVUS              308       4099
# MAJUTUS JA TOITLUSTUS                                422       5697
# MUUD TEENINDAVAD TEGEVUSED                           178       2339
# MÄETÖÖSTUS                                            16        225
# PÕLLUMAJANDUS, METSAMAJANDUS JA KALAPÜÜK             166       2181
# TERVISHOID JA SOTSIAALHOOLEKANNE                     276       3709
# TÖÖTLEV TÖÖSTUS                                      723       9847
# VEEVARUSTUS; KANALISATSIOON; JÄÄTME- JA SAASTEK...    37        513
# VEONDUS JA LAONDUS                                   357       4786

# %%
#Number of employees in the enterprises: 20-49
filtered2 = taxes_data[(taxes_data['Tootajaid'] > 19) & (taxes_data['Tootajaid'] < 50) ][['tegevusvaldkond','Nimi','Tootajaid']]
filtered2.groupby(['tegevusvaldkond']).agg({'Nimi':'count','Tootajaid':'sum'})
# Out:
#                                                     Nimi  Tootajaid
# tegevusvaldkond
# 0                                                     10        286
#  AVALIK HALDUS JA RIIGIKAITSE; KOHUSTUSLIK SOTS...    39       1314
# EHITUS                                               287       8118
# ELEKTRIENERGIA, GAASI, AURU JA KONDITSIONEERITU...    20        602
# FINANTS- JA KINDLUSTUSTEGEVUS                         40       1164
# HALDUS- JA ABITEGEVUSED                              176       5282
# HARIDUS                                              604      19727
# HULGI- JA JAEKAUBANDUS; MOOTORSÕIDUKITE JA MOOT...   365      11140
# INFO JA SIDE                                         102       3072
# KINNISVARAALANE TEGEVUS                               60       1697
# KUNST, MEELELAHUTUS JA VABA AEG                      136       3969
# KUTSE-, TEADUS- JA TEHNIKAALANE TEGEVUS              150       4463
# MAJUTUS JA TOITLUSTUS                                230       6786
# MUUD TEENINDAVAD TEGEVUSED                            92       2711
# MÄETÖÖSTUS                                            23        779
# PÕLLUMAJANDUS, METSAMAJANDUS JA KALAPÜÜK             121       3657
# TERVISHOID JA SOTSIAALHOOLEKANNE                     214       6426
# TÖÖTLEV TÖÖSTUS                                      583      18193
# VEEVARUSTUS; KANALISATSIOON; JÄÄTME- JA SAASTEK...    26        790
# VEONDUS JA LAONDUS                                   216       6235

# %%
#Number of employees in the enterprises: 50-99
filtered3 = taxes_data[(taxes_data['Tootajaid'] > 49) & (taxes_data['Tootajaid'] < 100) ][['tegevusvaldkond','Nimi','Tootajaid']]
filtered3.groupby(['tegevusvaldkond']).agg({'Nimi':'count','Tootajaid':'sum'})
# Out:
#                                                     Nimi  Tootajaid
# tegevusvaldkond
# 0                                                      2        139
#  AVALIK HALDUS JA RIIGIKAITSE; KOHUSTUSLIK SOTS...    55       4106
# EHITUS                                                51       3379
# ELEKTRIENERGIA, GAASI, AURU JA KONDITSIONEERITU...     7        483
# FINANTS- JA KINDLUSTUSTEGEVUS                         17       1285
# HALDUS- JA ABITEGEVUSED                               49       3390
# HARIDUS                                              264      17862
# HULGI- JA JAEKAUBANDUS; MOOTORSÕIDUKITE JA MOOT...   114       7950
# INFO JA SIDE                                          48       3351
# KINNISVARAALANE TEGEVUS                               13        810
# KUNST, MEELELAHUTUS JA VABA AEG                       38       2499
# KUTSE-, TEADUS- JA TEHNIKAALANE TEGEVUS               46       3059
# MAJUTUS JA TOITLUSTUS                                 46       3234
# MUUD TEENINDAVAD TEGEVUSED                            14        936
# MÄETÖÖSTUS                                             6        426
# PÕLLUMAJANDUS, METSAMAJANDUS JA KALAPÜÜK              18       1192
# TERVISHOID JA SOTSIAALHOOLEKANNE                      66       4618
# TÖÖTLEV TÖÖSTUS                                      265      18376
# VEEVARUSTUS; KANALISATSIOON; JÄÄTME- JA SAASTEK...    11        808
# VEONDUS JA LAONDUS                                    55       3542

# %%
#Number of employees in the enterprises: 100-249
filtered4 = taxes_data[(taxes_data['Tootajaid'] > 99) & (taxes_data['Tootajaid'] < 250) ][['tegevusvaldkond','Nimi','Tootajaid']]
filtered4.groupby(['tegevusvaldkond']).agg({'Nimi':'count','Tootajaid':'sum'})
# Out:
#                                                     Nimi  Tootajaid
# tegevusvaldkond
#  AVALIK HALDUS JA RIIGIKAITSE; KOHUSTUSLIK SOTS...    60       9091
# EHITUS                                                17       2448
# ELEKTRIENERGIA, GAASI, AURU JA KONDITSIONEERITU...     4        651
# FINANTS- JA KINDLUSTUSTEGEVUS                         11       1678
# HALDUS- JA ABITEGEVUSED                               43       7157
# HARIDUS                                               80      10312
# HULGI- JA JAEKAUBANDUS; MOOTORSÕIDUKITE JA MOOT...    73      10996
# INFO JA SIDE                                          30       4542
# KINNISVARAALANE TEGEVUS                                6        953
# KUNST, MEELELAHUTUS JA VABA AEG                       21       3219
# KUTSE-, TEADUS- JA TEHNIKAALANE TEGEVUS               23       3642
# MAJUTUS JA TOITLUSTUS                                 28       4422
# MUUD TEENINDAVAD TEGEVUSED                             7        907
# PÕLLUMAJANDUS, METSAMAJANDUS JA KALAPÜÜK               4        528
# TERVISHOID JA SOTSIAALHOOLEKANNE                      35       5230
# TÖÖTLEV TÖÖSTUS                                      160      24877
# VEEVARUSTUS; KANALISATSIOON; JÄÄTME- JA SAASTEK...     1        125
# VEONDUS JA LAONDUS                                    38       6153

# %%
#Number of employees in the enterprises: 250 and more
filtered5 = taxes_data[(taxes_data['Tootajaid'] > 250)][['tegevusvaldkond','Nimi','Tootajaid']]
filtered5.groupby(['tegevusvaldkond']).agg({'Nimi':'count','Tootajaid':'sum'})
# Out:
#                                                     Nimi  Tootajaid
# tegevusvaldkond
# 0                                                      2        935
#  AVALIK HALDUS JA RIIGIKAITSE; KOHUSTUSLIK SOTS...    30      26751
# EHITUS                                                 6       1980
# ELEKTRIENERGIA, GAASI, AURU JA KONDITSIONEERITU...     4       2861
# FINANTS- JA KINDLUSTUSTEGEVUS                         10       6929
# HALDUS- JA ABITEGEVUSED                               21      15384
# HARIDUS                                               12      11409
# HULGI- JA JAEKAUBANDUS; MOOTORSÕIDUKITE JA MOOT...    41      26543
# INFO JA SIDE                                          16       9047
# KUNST, MEELELAHUTUS JA VABA AEG                        6       2198
# KUTSE-, TEADUS- JA TEHNIKAALANE TEGEVUS                4       2146
# MAJUTUS JA TOITLUSTUS                                  9       3644
# MUUD TEENINDAVAD TEGEVUSED                             2        694
# MÄETÖÖSTUS                                             2       1899
# TERVISHOID JA SOTSIAALHOOLEKANNE                      25      24527
# TÖÖTLEV TÖÖSTUS                                       53      25738
# VEEVARUSTUS; KANALISATSIOON; JÄÄTME- JA SAASTEK...     3       1077
# VEONDUS JA LAONDUS                                    16      10212
